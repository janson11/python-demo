# %%
import urllib3
url = "http://jandan.net/p/date/2021/03/23"
# 创建一个 PoolManager 对象，命名为 http
http = urllib3.PoolManager()
response = http.request("GET",url)
response_data = response.data
html_context =response_data.decode()
print(html_context)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="zh">
# <head>
# <title>
# 2021年03月23日 - 煎蛋
# </title>
# <meta name="keywords" content=""/>
# <meta name="description" content=""/>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="renderer" content="webkit">
# <meta http-equiv="Window-target" Content="_top">
# <meta name="baidu-site-verification" content="9wC0PEtTmEqSNlOk"/>
# <meta http-equiv="mobile-agent" content="format=html5; url=//i.jandan.net/p/date/2021/03/23">
# <meta name="robots" content="index,nofollow">
# <link rel="stylesheet" href="//cdn.jandan.net/static/min/b1ac6f06f95ff8b640a85a2aa41e1ebeUsJnZzCx.29111008.css" type="text/css" media="screen"/>
# <link rel="apple-touch-icon" href="//cdn.jandan.net/static/img/appicon.png">
# <link rel="shortcut icon" href="//cdn.jandan.net/static/img/favicon.ico"/>
# <script>if (window != top)top.location.href = window.location.href;</script>
# ...

# %%
fo = open("jiandan.html","w",encoding="utf-8")
fo.write(html_context)
fo.close()

# %%
# 下载文件
def download_content(url):
    http = urllib3.PoolManager()
    response = http.request("GET",url)
    response_data = response.data
    html_content = response_data.decode()
    return html_content

# 保存文件
def save_to_file(filename,content):
    fo = open(filename,"w",encoding="utf-8")
    fo.write(content)
    fo.close()  

url = "http://jandan.net/"
html_content = download_content(url)
save_to_file("jiandan1.html",html_context)

# %%
url = "https://movie.douban.com/tv"
html_douban_content = download_content(url)
save_to_file("douban_tv.html",html_douban_content)

# %%
from selenium import webdriver
brow = webdriver.Chrome()
brow.get(url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# D:\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#
# ...
